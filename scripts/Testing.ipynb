# %%
# %run tsv_to_json.py "/home/lgutierr/Documents/AIRR-seqAA/scripts/5eaca36e-c0b9-4be5-aeaa-bc1d230af791.tsv"
# Out:
# Written successfully to /home/lgutierr/Documents/AIRR-seqAA/scripts/5eaca36e-c0b9-4be5-aeaa-bc1d230af791.json

# %%
# %run parser_.py "/home/lgutierr/Documents/AIRR-seqAA/adaptive/iseq/5eaca36e-c0b9-4be5-aeaa-bc1d230af791.samples.tsv" "/home/lgutierr/Documents/AIRR-seqAA/Mapping_Files/NK_ColumnMappings.tsv" "/home/lgutierr/Documents/AIRR-seqAA/Mapping_Files/NK_TagMappings.tsv" "5eaca36e-c0b9-4be5-aeaa-bc1d230af791"
# Out:
# Mapping
#        Adaptive-name                       AIRR-name  \
# 0        sample_name                       sample_id
# 1            species                      species.id
# 2            species                   species.label
# 3              locus                pcr_target_locus
# 4    counting_method               software_versions
# 5          test_name             sequencing_platform
# 6         primer_set                             NaN
# 7    product_subtype                  sequencing_kit
# 8             kit_id  library_generation_kit_version
# 9   sample_amount_ng                 template_amount
# 10     total_t_cells                     cell_number
#
#                 Adaptive-example                  AIRR-example  \
# 0   Healthy_Subject_10_CD8_Naive  Healthy_Subject_10_CD8_Naive
# 1                          Human                NCBITAXON:9606
# 2                          Human                  Homo Sapiens
# ...

# %%
# %run -i parser_.py -h
# Out:
# usage: parser_.py [-h] [-v] TSV_file map_file tag_file
#
# positional arguments:
#   TSV_file       Indicate the full path to where the TSV from adaptive file is
#                  found
#   map_file       Indicate the full path to where the mapping file is found
#   tag_file       Indicate the full path to where the tagging file is found
#
# optional arguments:
#   -h, --help     show this help message and exit
#   -v, --verbose  Run the program in verbose mode.

# %%
[item.split(",") for item in tsv_immonuseq["sample_catalog_tags"].to_list()]
# Out:
# [['Cluster of Differentiation (CD):CD45RA+',
#   'Cluster of Differentiation (CD):CD62L+',
#   'Cluster of Differentiation (CD):CD8+',
#   'Subject:Control',
#   'Tissue Source:Naive T cells',
#   'Tissue Source:PBMC'],
#  ['Cluster of Differentiation (CD):CD45RA-',
#   'Cluster of Differentiation (CD):CD45RO+',
#   'Cluster of Differentiation (CD):CD8+',
#   'Subject:Control',
#   'Tissue Source:Memory T cells',
#   'Tissue Source:PBMC'],
#  ['Cluster of Differentiation (CD):CD8+',
#   'Nervous System Diseases:Multiple Sclerosis',
#   'Tissue Source:PBMC'],
#  ['Cluster of Differentiation (CD):CD45RA+',
#   'Cluster of Differentiation (CD):CD62L+',
#   'Cluster of Differentiation (CD):CD8+',
#   'Subject:Control',
#   'Tissue Source:Naive T cells',
#   'Tissue Source:PBMC'],
#  ['Cluster of Differentiation (CD):CD45RA-',
#   'Cluster of Differentiation (CD):CD45RO+',
#   'Cluster of Differentiation (CD):CD8+',
#   'Subject:Control',
#   'Tissue Source:Memory T cells',
# ...
